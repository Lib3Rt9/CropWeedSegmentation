# %%
# !pip install matplotlib
# !pip install opencv-python
# !pip install scikit-image
# !pip install wheel
# !pip install pandas
# !pip install scikit-learn scipy
# !pip install keras
# !pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/phucpg/.local/lib/python3.7/site-packages (3.5.2)
# Requirement already satisfied: packaging>=20.0 in /home/phucpg/.local/lib/python3.7/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/phucpg/.local/lib/python3.7/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/phucpg/.local/lib/python3.7/site-packages (from matplotlib) (1.4.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/phucpg/.local/lib/python3.7/site-packages (from matplotlib) (9.1.1)
# Requirement already satisfied: numpy>=1.17 in /home/phucpg/.local/lib/python3.7/site-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/phucpg/.local/lib/python3.7/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/phucpg/.local/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/phucpg/.local/lib/python3.7/site-packages (from matplotlib) (4.33.3)
# Requirement already satisfied: typing-extensions in /home/phucpg/.local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (4.2.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.12.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/phucpg/.local/lib/python3.7/site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /home/phucpg/.local/lib/python3.7/site-packages (from opencv-python) (1.21.6)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-image in /home/phucpg/.local/lib/python3.7/site-packages (0.19.3)
# Requirement already satisfied: imageio>=2.4.1 in /home/phucpg/.local/lib/python3.7/site-packages (from scikit-image) (2.19.3)
# Requirement already satisfied: packaging>=20.0 in /home/phucpg/.local/lib/python3.7/site-packages (from scikit-image) (21.3)
# Requirement already satisfied: scipy>=1.4.1 in /home/phucpg/.local/lib/python3.7/site-packages (from scikit-image) (1.7.3)
# Requirement already satisfied: networkx>=2.2 in /home/phucpg/.local/lib/python3.7/site-packages (from scikit-image) (2.6.3)
# Requirement already satisfied: numpy>=1.17.0 in /home/phucpg/.local/lib/python3.7/site-packages (from scikit-image) (1.21.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/phucpg/.local/lib/python3.7/site-packages (from scikit-image) (2021.11.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/phucpg/.local/lib/python3.7/site-packages (from scikit-image) (1.3.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /home/phucpg/.local/lib/python3.7/site-packages (from scikit-image) (9.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/phucpg/.local/lib/python3.7/site-packages (from packaging>=20.0->scikit-image) (3.0.9)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wheel in /home/phucpg/.local/lib/python3.7/site-packages (0.37.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/phucpg/.local/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /home/phucpg/.local/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/phucpg/.local/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/phucpg/.local/lib/python3.7/site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas) (1.12.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/phucpg/.local/lib/python3.7/site-packages (1.0.2)
# Requirement already satisfied: scipy in /home/phucpg/.local/lib/python3.7/site-packages (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in /home/phucpg/.local/lib/python3.7/site-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /home/phucpg/.local/lib/python3.7/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/phucpg/.local/lib/python3.7/site-packages (from scikit-learn) (3.1.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in /home/phucpg/.local/lib/python3.7/site-packages (2.9.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /home/phucpg/.local/lib/python3.7/site-packages (2.9.1)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (4.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: setuptools in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.12.0)
# Requirement already satisfied: numpy>=1.20 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (1.47.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: packaging in /home/phucpg/.local/lib/python3.7/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/phucpg/.local/lib/python3.7/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/lib/python3/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.21.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.8.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/phucpg/.local/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/phucpg/.local/lib/python3.7/site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/phucpg/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/phucpg/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/phucpg/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/phucpg/.local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/phucpg/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /home/phucpg/.local/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/phucpg/.local/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/phucpg/.local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)

# %%
#importing libraries
import matplotlib.pyplot as plt
import numpy as np
import cv2
from os import listdir
from skimage import io

#specifying paths
path1='/storage/phucpg/test1/RedEdge_filtered/mask/'
path2='/storage/phucpg/test1/RedEdge_filtered/color/'
path3='/storage/phucpg/test1/RedEdge_filtered/RGB/'
print(len(listdir(path1)))

#printing the first 10 files
for filename in listdir(path1)[25:30]:
  
  image_r=cv2.imread(path1 + filename)
  # image_r = cv2.cvtColor(image_r, cv2.COLOR_BGR2RGB)
  plt.subplot(1,3,1)
  plt.imshow(image_r)

  image_r=cv2.imread(path2 + filename)
  # image_r = cv2.cvtColor(image_r, cv2.COLOR_BGR2RGB)
  plt.subplot(1,3,2)
  plt.imshow(image_r)
  # print(image_r[:,:,2])
  # print(np.count_nonzero(image_r[:,:,2]))

  image_r=cv2.imread(path3 + filename)
  image_r = cv2.cvtColor(image_r, cv2.COLOR_BGR2RGB)
  plt.subplot(1,3,3)
  plt.imshow(image_r)
  
  plt.show()
# Out:
# 556

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

from os import listdir
from os.path import isfile, join
import pandas as pd
from sklearn.model_selection import train_test_split
import gc; gc.enable() # memory is tight

from keras import layers, models
from keras import backend as K
from tensorflow.keras.optimizers import Adam

N=556
TRAIN_SIZE=500
TEST_SIZE=56
BATCH_SIZE = 10
EDGE_CROP = 16
NB_EPOCHS = 30
GAUSSIAN_NOISE = 0.1
UPSAMPLE_MODE = 'DECONV'
# downsampling inside the network
NET_SCALING = None
# downsampling in preprocessing
IMG_SCALING = (1, 1)
# number of validation images to use
VALID_IMG_COUNT = 552
# maximum number of steps_per_epoch in training
MAX_TRAIN_STEPS = 200
AUGMENT_BRIGHTNESS = False
resized_shape=(256,256)
train_mask=[]
test_mask=[]
train_images=[]
test_images=[]
for i,file in enumerate(listdir(path1)):
  if i<TRAIN_SIZE:
    train_images.append(path3+file)
    train_mask.append(path2+file)

  else:
    test_images.append(path3+file)
    test_mask.append(path2+file)
df_train=pd.DataFrame(np.column_stack([train_images,train_mask]),columns=['images','masks'])
df_test=pd.DataFrame(np.column_stack([test_images,test_mask]),columns=['images','masks'])

df1 = df_train.sort_values(by='images')['images'].reset_index()
df2 = df_train.sort_values(by='masks')['masks'].reset_index()
# df2 = df.sort_values(by='b')['b']
df_train['images'] = df1['images']
df_train['masks'] = df2['masks']
del df1, df2

df1 = df_test.sort_values(by='images')['images'].reset_index()
df2 = df_test.sort_values(by='masks')['masks'].reset_index()
# df2 = df.sort_values(by='b')['b']
df_test['images'] = df1['images']
df_test['masks'] = df2['masks']
del df1, df2

# %%
# Checking size of training dataframe
len(df_train)
df_train
# Out:
#                                                 images  \
# 0    /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 1    /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 2    /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 3    /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 4    /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# ..                                                 ...
# 495  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 496  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 497  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 498  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 499  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
#
#                                                  masks
# 0    /storage/phucpg/test1/RedEdge_filtered/color/f...
# 1    /storage/phucpg/test1/RedEdge_filtered/color/f...
# 2    /storage/phucpg/test1/RedEdge_filtered/color/f...
# 3    /storage/phucpg/test1/RedEdge_filtered/color/f...
# 4    /storage/phucpg/test1/RedEdge_filtered/color/f...
# ..                                                 ...
# 495  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 496  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 497  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 498  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 499  /storage/phucpg/test1/RedEdge_filtered/color/f...
#
# [500 rows x 2 columns]

# %%
# Checking size of testing dataframe
len(df_test)
df_test
# Out:
#                                                images  \
# 0   /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 1   /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 2   /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 3   /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 4   /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 5   /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 6   /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 7   /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 8   /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 9   /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 10  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 11  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 12  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 13  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 14  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 15  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 16  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 17  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 18  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 19  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 20  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 21  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 22  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 23  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 24  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 25  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 26  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 27  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 28  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 29  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 30  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 31  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 32  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 33  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 34  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 35  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 36  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 37  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 38  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 39  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 40  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 41  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 42  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 43  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 44  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 45  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 46  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 47  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 48  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 49  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 50  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 51  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 52  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 53  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 54  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
# 55  /storage/phucpg/test1/RedEdge_filtered/RGB/fra...
#
#                                                 masks
# 0   /storage/phucpg/test1/RedEdge_filtered/color/f...
# 1   /storage/phucpg/test1/RedEdge_filtered/color/f...
# 2   /storage/phucpg/test1/RedEdge_filtered/color/f...
# 3   /storage/phucpg/test1/RedEdge_filtered/color/f...
# 4   /storage/phucpg/test1/RedEdge_filtered/color/f...
# 5   /storage/phucpg/test1/RedEdge_filtered/color/f...
# 6   /storage/phucpg/test1/RedEdge_filtered/color/f...
# 7   /storage/phucpg/test1/RedEdge_filtered/color/f...
# 8   /storage/phucpg/test1/RedEdge_filtered/color/f...
# 9   /storage/phucpg/test1/RedEdge_filtered/color/f...
# 10  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 11  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 12  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 13  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 14  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 15  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 16  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 17  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 18  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 19  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 20  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 21  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 22  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 23  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 24  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 25  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 26  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 27  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 28  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 29  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 30  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 31  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 32  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 33  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 34  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 35  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 36  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 37  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 38  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 39  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 40  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 41  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 42  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 43  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 44  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 45  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 46  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 47  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 48  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 49  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 50  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 51  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 52  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 53  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 54  /storage/phucpg/test1/RedEdge_filtered/color/f...
# 55  /storage/phucpg/test1/RedEdge_filtered/color/f...

# %%
def create_mask(maskpath,img_shape):
  mask=np.zeros(shape=(img_shape[0],img_shape[1],1))
  mask_img=cv2.imread(maskpath)
  mask_img=mask_img[:,:,2]
  for i in range(img_shape[0]):
    for j in range(img_shape[1]):
      if mask_img[i,j]>0:
        mask[i,j,0]=1
      else:
        mask[i,j,0]=0
  return mask

def create_images_generator(df_in, batch_size, resized_shape):
  batch_image = []
  batch_mask = []
  df_in_list = (df_in).values.tolist()
  # np.random.shuffle(df_in_list) 
    
  while True:
      for image_path, mask_path in df_in_list:
        
        image_r = cv2.imread(image_path)
        image_r = cv2.cvtColor(image_r, cv2.COLOR_BGR2RGB)
        mask_r = create_mask(mask_path, image_r.shape)
        # print("shape is ",image_r.shape) is 360x480
        image_r = cv2.resize(image_r,(resized_shape[1], resized_shape[0]))
        mask_r = cv2.resize(mask_r,(resized_shape[1], resized_shape[0]))          
                    
        batch_image.append(image_r)
        batch_mask.append(mask_r)
        
        if len(batch_mask)>=batch_size:
            yield np.float32(np.stack((batch_image), 0)/255.0), np.stack(np.float32(np.expand_dims(batch_mask, -1)), 0)
            batch_image, batch_mask = [], []

# %%
from keras.preprocessing.image import ImageDataGenerator
args_dg = dict(featurewise_center = False, 
               samplewise_center = False, 
               rotation_range = 2, 
               width_shift_range = 0.1, 
               shear_range = 0.01,
               zoom_range = [0.9, 1.1], 
               horizontal_flip = False, 
               vertical_flip = False,
               fill_mode = 'constant',
               data_format = 'channels_last')

if AUGMENT_BRIGHTNESS:
    args_dg['brightness_range'] = [0.5, 1.5]

image_gen = ImageDataGenerator(**args_dg)

if AUGMENT_BRIGHTNESS:
    args_dg.pop('brightness_range')
mask_gen = ImageDataGenerator(**args_dg)

# In[]
def make_augment_generator(img_mask_gen, seed=None):
    np.random.seed(seed if seed is not None else np.random.choice(range(9999)))
    
    for img_in, mask_in in img_mask_gen:
        seed = np.random.choice(range(9999))
        aug_img_in = image_gen.flow(255*img_in, 
                                 batch_size=img_in.shape[0],
                                 seed = seed, 
                                 shuffle=True)
        aug_mask_in = mask_gen.flow(mask_in, 
                                    batch_size=img_in.shape[0],
                                    seed=seed,
                                    shuffle=True)
        yield next(aug_img_in)/255.0, next(aug_mask_in)

def calc_IOU(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    intersection = K.sum(y_true_f*y_pred_f)
    
    return (2*(intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
def calc_IOU_loss(y_true, y_pred):
    return -calc_IOU(y_true, y_pred)

# In[]
def upsample_conv(filters, kernel_size, strides, padding):
    return layers.Conv2DTranspose(filters, kernel_size, strides=strides, padding=padding)

def upsample_simple(filters, kernel_size, strides, padding):
    return layers.UpSampling2D(strides)

if UPSAMPLE_MODE=='DECONV':
    upsample=upsample_conv
else:
    upsample=upsample_simple

def create_unet():
    
    # input_img = layers.Input(batch_img.shape[1:], name = 'RGB_Input')
    input_img = layers.Input((resized_shape[0],resized_shape[1],3), name = 'RGB_Input')
    pp_in_layer = input_img
             
    c1 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(pp_in_layer)
    c1 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)
    
    c2 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)
    
    c3 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2)) (c3)
    
    c4 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D(pool_size=(2, 2)) (c4)
    
    c5 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p4)
    c5 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c5)
    
    
    u6 = upsample(64, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c4], axis=3)
    c6 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c6)
    
    u7 = upsample(32, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c3], axis=3)
    c7 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c7)
    
    u8 = upsample(16, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, c2], axis=3)
    c8 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(u8)
    c8 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(c8)
    
    u9 = upsample(8, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = layers.concatenate([u9, c1], axis=3)
    c9 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(u9)
    c9 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c9)
    
    d = layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)   
    if NET_SCALING is not None:
      d = layers.UpSampling2D(NET_SCALING)(d)
     
    seg_model = models.Model(inputs=[input_img], outputs=[d])
    seg_model.summary()
    
    return seg_model

# %%
# In[]

model = create_unet()
model.compile(optimizer=Adam(lr=1e-3),
              loss=calc_IOU_loss, metrics=[calc_IOU])
# In[]
# history = model.fit_generator(train_gen,
#             samples_per_epoch=40,
#                               nb_epoch=2)    
 
train_gen = create_images_generator(df_train, batch_size=BATCH_SIZE, resized_shape=resized_shape)
valid_gen = create_images_generator(df_test, batch_size=BATCH_SIZE, resized_shape=resized_shape)
# aug_gen = make_augment_generator(train_gen)
val_img, val_mask = next(valid_gen)  


#UNCOMMENT IF NO CHECKPOINT MODEL AVAILABLE
history=model.fit_generator(train_gen,
 steps_per_epoch=5,
 epochs=50,
 validation_data=(val_img, val_mask) )
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  RGB_Input (InputLayer)         [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 8)  224         ['RGB_Input[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 8)  584         ['conv2d_19[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 8)  0          ['conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 16  1168        ['max_pooling2d_4[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 16  2320        ['conv2d_21[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 16)  0           ['conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 32)   4640        ['max_pooling2d_5[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 32)   9248        ['conv2d_23[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 32)  0           ['conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 64)   18496       ['max_pooling2d_6[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 64)   36928       ['conv2d_25[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 128)  73856       ['max_pooling2d_7[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_27[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 32, 32, 64)  32832       ['conv2d_28[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 64)   73792       ['concatenate_4[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 64)   36928       ['conv2d_29[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 32)  8224        ['conv2d_30[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_5[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_5[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 32)   9248        ['conv2d_31[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 128, 128, 16  2064       ['conv2d_32[0][0]']
#  spose)                         )
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_6[0][0]',
#                                 )                                 'conv2d_22[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 16  4624        ['concatenate_6[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 128, 128, 16  2320        ['conv2d_33[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 256, 256, 8)  520        ['conv2d_34[0][0]']
#  spose)
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 16  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'conv2d_20[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 8)  1160        ['concatenate_7[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 256, 256, 8)  584         ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 1)  9           ['conv2d_36[0][0]']
#
# ==================================================================================================
# Total params: 485,817
# Trainable params: 485,817
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /home/phucpg/.local/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/50
# 5/5 [==============================] - 22s 5s/step - loss: -0.1117 - calc_IOU: 0.1117 - val_loss: -0.0687 - val_calc_IOU: 0.0687
# Epoch 2/50
# 5/5 [==============================] - 17s 4s/step - loss: -0.0684 - calc_IOU: 0.0684 - val_loss: -0.0695 - val_calc_IOU: 0.0695
# Epoch 3/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.0638 - calc_IOU: 0.0638 - val_loss: -0.0716 - val_calc_IOU: 0.0716
# Epoch 4/50
# 5/5 [==============================] - 19s 4s/step - loss: -0.0209 - calc_IOU: 0.0209 - val_loss: -0.0761 - val_calc_IOU: 0.0761
# Epoch 5/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.0127 - calc_IOU: 0.0127 - val_loss: -0.0789 - val_calc_IOU: 0.0789
# Epoch 6/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.0737 - calc_IOU: 0.0737 - val_loss: -0.0793 - val_calc_IOU: 0.0793
# Epoch 7/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.0252 - calc_IOU: 0.0252 - val_loss: -0.0790 - val_calc_IOU: 0.0790
# Epoch 8/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.0417 - calc_IOU: 0.0417 - val_loss: -0.0797 - val_calc_IOU: 0.0797
# Epoch 9/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.0502 - calc_IOU: 0.0502 - val_loss: -0.0798 - val_calc_IOU: 0.0798
# Epoch 10/50
# 5/5 [==============================] - 19s 4s/step - loss: -0.0553 - calc_IOU: 0.0553 - val_loss: -0.0808 - val_calc_IOU: 0.0808
# Epoch 11/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.1397 - calc_IOU: 0.1397 - val_loss: -0.0959 - val_calc_IOU: 0.0959
# Epoch 12/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.0949 - calc_IOU: 0.0949 - val_loss: -0.1028 - val_calc_IOU: 0.1028
# Epoch 13/50
# 5/5 [==============================] - 19s 4s/step - loss: -0.0908 - calc_IOU: 0.0908 - val_loss: -0.0973 - val_calc_IOU: 0.0973
# Epoch 14/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.0235 - calc_IOU: 0.0235 - val_loss: -0.0826 - val_calc_IOU: 0.0826
# Epoch 15/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.0150 - calc_IOU: 0.0150 - val_loss: -0.1120 - val_calc_IOU: 0.1120
# Epoch 16/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.0987 - calc_IOU: 0.0987 - val_loss: -0.1423 - val_calc_IOU: 0.1423
# Epoch 17/50
# 5/5 [==============================] - 24s 5s/step - loss: -0.0385 - calc_IOU: 0.0385 - val_loss: -0.1566 - val_calc_IOU: 0.1566
# Epoch 18/50
# 5/5 [==============================] - 27s 6s/step - loss: -0.0851 - calc_IOU: 0.0851 - val_loss: -0.2740 - val_calc_IOU: 0.2740
# Epoch 19/50
# 5/5 [==============================] - 46s 11s/step - loss: -0.2492 - calc_IOU: 0.2492 - val_loss: -0.2888 - val_calc_IOU: 0.2888
# Epoch 20/50
# 5/5 [==============================] - 31s 7s/step - loss: -0.1868 - calc_IOU: 0.1868 - val_loss: -0.3217 - val_calc_IOU: 0.3217
# Epoch 21/50
# 5/5 [==============================] - 16s 4s/step - loss: -0.4469 - calc_IOU: 0.4469 - val_loss: -0.3571 - val_calc_IOU: 0.3571
# Epoch 22/50
# 5/5 [==============================] - 27s 6s/step - loss: -0.3197 - calc_IOU: 0.3197 - val_loss: -0.3807 - val_calc_IOU: 0.3807
# Epoch 23/50
# 5/5 [==============================] - 20s 5s/step - loss: -0.4365 - calc_IOU: 0.4365 - val_loss: -0.2477 - val_calc_IOU: 0.2477
# Epoch 24/50
# 5/5 [==============================] - 36s 8s/step - loss: -0.0377 - calc_IOU: 0.0377 - val_loss: -0.1609 - val_calc_IOU: 0.1609
# Epoch 25/50
# 5/5 [==============================] - 27s 6s/step - loss: -0.0568 - calc_IOU: 0.0568 - val_loss: -0.3816 - val_calc_IOU: 0.3816
# Epoch 26/50
# 5/5 [==============================] - 22s 5s/step - loss: -0.3314 - calc_IOU: 0.3314 - val_loss: -0.3752 - val_calc_IOU: 0.3752
# Epoch 27/50
# 5/5 [==============================] - 16s 4s/step - loss: -0.1116 - calc_IOU: 0.1116 - val_loss: -0.4320 - val_calc_IOU: 0.4320
# Epoch 28/50
# 5/5 [==============================] - 21s 4s/step - loss: -0.2183 - calc_IOU: 0.2183 - val_loss: -0.4139 - val_calc_IOU: 0.4139
# Epoch 29/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.3594 - calc_IOU: 0.3594 - val_loss: -0.5282 - val_calc_IOU: 0.5282
# Epoch 30/50
# 5/5 [==============================] - 29s 6s/step - loss: -0.3820 - calc_IOU: 0.3820 - val_loss: -0.5163 - val_calc_IOU: 0.5163
# Epoch 31/50
# 5/5 [==============================] - 18s 4s/step - loss: -0.5773 - calc_IOU: 0.5773 - val_loss: -0.4752 - val_calc_IOU: 0.4752
# Epoch 32/50
# 5/5 [==============================] - 19s 4s/step - loss: -0.4768 - calc_IOU: 0.4768 - val_loss: -0.5609 - val_calc_IOU: 0.5609
# Epoch 33/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.5390 - calc_IOU: 0.5390 - val_loss: -0.4661 - val_calc_IOU: 0.4661
# Epoch 34/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.3552 - calc_IOU: 0.3552 - val_loss: -0.5489 - val_calc_IOU: 0.5489
# Epoch 35/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.3863 - calc_IOU: 0.3863 - val_loss: -0.4927 - val_calc_IOU: 0.4927
# Epoch 36/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.4437 - calc_IOU: 0.4437 - val_loss: -0.4889 - val_calc_IOU: 0.4889
# Epoch 37/50
# 5/5 [==============================] - 19s 4s/step - loss: -0.2782 - calc_IOU: 0.2782 - val_loss: -0.4344 - val_calc_IOU: 0.4344
# Epoch 38/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.2925 - calc_IOU: 0.2925 - val_loss: -0.5314 - val_calc_IOU: 0.5314
# Epoch 39/50
# 5/5 [==============================] - 19s 4s/step - loss: -0.4371 - calc_IOU: 0.4371 - val_loss: -0.4880 - val_calc_IOU: 0.4880
# Epoch 40/50
# 5/5 [==============================] - 21s 4s/step - loss: -0.3873 - calc_IOU: 0.3873 - val_loss: -0.5657 - val_calc_IOU: 0.5657
# Epoch 41/50
# 5/5 [==============================] - 41s 9s/step - loss: -0.5986 - calc_IOU: 0.5986 - val_loss: -0.4159 - val_calc_IOU: 0.4159
# Epoch 42/50
# 5/5 [==============================] - 42s 8s/step - loss: -0.4798 - calc_IOU: 0.4798 - val_loss: -0.6002 - val_calc_IOU: 0.6002
# Epoch 43/50
# 5/5 [==============================] - 43s 9s/step - loss: -0.5766 - calc_IOU: 0.5766 - val_loss: -0.5801 - val_calc_IOU: 0.5801
# Epoch 44/50
# 5/5 [==============================] - 56s 13s/step - loss: -0.4663 - calc_IOU: 0.4663 - val_loss: -0.5530 - val_calc_IOU: 0.5530
# Epoch 45/50
# 5/5 [==============================] - 61s 14s/step - loss: -0.4341 - calc_IOU: 0.4341 - val_loss: -0.6202 - val_calc_IOU: 0.6202
# Epoch 46/50
# 5/5 [==============================] - 18s 4s/step - loss: -0.5833 - calc_IOU: 0.5833 - val_loss: -0.6376 - val_calc_IOU: 0.6376
# Epoch 47/50
# 5/5 [==============================] - 21s 4s/step - loss: -0.4762 - calc_IOU: 0.4762 - val_loss: -0.5964 - val_calc_IOU: 0.5964
# Epoch 48/50
# 5/5 [==============================] - 21s 4s/step - loss: -0.4805 - calc_IOU: 0.4805 - val_loss: -0.5322 - val_calc_IOU: 0.5322
# Epoch 49/50
# 5/5 [==============================] - 20s 4s/step - loss: -0.4993 - calc_IOU: 0.4993 - val_loss: -0.5664 - val_calc_IOU: 0.5664
# Epoch 50/50
# 5/5 [==============================] - 21s 4s/step - loss: -0.5002 - calc_IOU: 0.5002 - val_loss: -0.6060 - val_calc_IOU: 0.6060

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
#plot

results=model.evaluate(val_img,val_mask)
print("The accuracy is ")
print(results)
acc=history.history['calc_IOU']
val_acc=history.history['val_calc_IOU']
epochs=range(1,len(acc)+1)
plt.plot(epochs,acc,'-b',label="TRAIN IOU")
plt.plot(epochs,val_acc,'-r',label="VAL IOU")
# plt.title("ACCURACY")
plt.xlabel("EPOCHS")
plt.ylabel("IOU")
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: -0.6060 - calc_IOU: 0.6060
# The accuracy is
# [-0.6060119271278381, 0.6060119271278381]
